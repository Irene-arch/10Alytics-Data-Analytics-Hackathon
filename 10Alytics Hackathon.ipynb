# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Assessment

# %%
deaths_cause = pd.read_csv('1. annual-number-of-deaths-by-cause.csv')
deaths_cause.sample(10)
# Out:
#                                   Entity Code  Year  \
# 5228                         Saint Lucia  LCA  2008
# 5847                         South Sudan  SSD  1994
# 4914                         Philippines  PHL  1994
# 1831  Eastern Mediterranean Region (WHO)  NaN  2006
# 49                  African Region (WHO)  NaN  2009
# 5555                           Singapore  SGP  1995
# 5694                        South Africa  ZAF  1990
# 6977        Western Pacific Region (WHO)  NaN  1994
# 5386                        Saudi Arabia  SAU  2006
# 3906          Middle East & North Africa  NaN  2002
#
#      Number of executions (Amnesty International)  Meningitis  \
# 5228                                          NaN         2.0
# 5847                                          NaN      2292.0
# 4914                                          NaN      3637.0
# 1831                                          NaN     40719.0
# 49                                            NaN    187657.0
# ...

# %%
deaths_age_group = pd.read_csv('2. number-of-deaths-by-age-group.csv')
deaths_age_group.sample(10)
# Out:
#                         Entity Code  Year  Deaths 70+ years  \
# 268                  Argentina  ARG  2018            218973
# 2904                     Japan  JPN  2014           1037474
# 5094     Sao Tome and Principe  STP  2014               396
# 183                     Angola  AGO  1993             15286
# 1230                     Congo  COG  1990              4634
# 3651                    Mexico  MEX  2011            264390
# 2580                   Hungary  HUN  1990             77414
# 1070  Central African Republic  CAF  2010              6492
# 2602                   Hungary  HUN  2012             82028
# 3327                 Lithuania  LTU  2017             26217
#
#       Deaths 50-69 years  Deaths Age: 15-49 years  Deaths 5-14 years  \
# 268                85229                    32356               1457
# 2904              193388                    40532                966
# 5094                 237                      175                 25
# ...

# %%
docs_per_pop = pd.read_excel('3. Medical Doctors Per 10000 population.xlsx', header=2)
docs_per_pop.sample(10)
# Out:
#      IndicatorCode                                     Indicator  \
# 4080      HWF_0002                      Medical doctors (number)
# 7679      HWF_0004     Specialist medical practitioners (number)
# 2457      HWF_0001                  Medical doctors (per 10,000)
# 6090      HWF_0002                      Medical doctors (number)
# 5289      HWF_0002                      Medical doctors (number)
# 9261      HWF_0005  Medical doctors not further defined (number)
# 4255      HWF_0002                      Medical doctors (number)
# 5152      HWF_0002                      Medical doctors (number)
# 754       HWF_0001                  Medical doctors (per 10,000)
# 2084      HWF_0001                  Medical doctors (per 10,000)
#
#      ParentLocationCode   ParentLocation ThreeLocCode             Location  \
# 4080                EUR           Europe          BEL              Belgium
# 7679                AMR         Americas          MEX               Mexico
# ...

# %%
country_continent_codes = pd.read_csv('4. ISO 3166_country-and-continent-codes-list-csv.csv')
country_continent_codes.sample(10)
# Out:
#     Continent_Name Continent_Code                Country_Name  \
# 117           Asia             AS            Kuwait, State of
# 25   North America            NaN                      Belize
# 73          Europe             EU               Åland Islands
# 227           Asia             AS         Turkey, Republic of
# 242         Africa             AF                Burkina Faso
# 74          Europe             EU     France, French Republic
# 179         Africa             AF  Guinea-Bissau, Republic of
# 121         Africa             AF         Lesotho, Kingdom of
# 182           Asia             AS             Qatar, State of
# 114         Africa             AF          Kenya, Republic of
#
#     Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 117                      KW                       KWT           414.0
# 25                       BZ                       BLZ            84.0
# 73                       AX                       ALA           248.0
# ...

# %%
world_population = pd.read_csv('5. World Population.csv')
world_population.sample(10)
# Out:
#                              Entity Code  Year  \
# 23170                          Iran  IRN  1852
# 49490                        Taiwan  TWN  1963
# 19825                    Guadeloupe  GLP  2018
# 51333           Trinidad and Tobago  TTO  1945
# 24058                        Israel  ISR  1891
# 20426                        Guinea  GIN  1957
# 14278                       Ecuador  ECU  1844
# 33191                      Mongolia  MNG  2005
# 43300                         Samoa  WSM  2003
# 13073  Democratic Republic of Congo  COD  1932
#
#        Population (historical estimates)
# 23170                            7594883
# 49490                           12200155
# 19825                             396273
# 51333                             560222
# 24058                             316578
# 20426                            3342379
# 14278                             740051
# 33191                            2559258
# 43300                             187455
# ...

# %%
gdp = pd.read_excel('6. Current health expenditure (% of GDP).xlsx', header=5)
gdp.sample(10)
# Out:
#                               Aruba  ABW  \
# 253                   Venezuela, RB  VEN
# 14                       Azerbaijan  AZE
# 203                      South Asia  SAS
# 165                      Mauritania  MRT
# 34                           Canada  CAN
# 232                        Thailand  THA
# 35   Central Europe and the Baltics  CEB
# 157                            Mali  MLI
# 247                         Ukraine  UKR
# 128                         Lao PDR  LAO
#
#      Current health expenditure (% of GDP)  Unnamed: 3  Unnamed: 4  \
# 253  Current health expenditure (% of GDP)    7.334273    7.850638
# 14   Current health expenditure (% of GDP)    2.948944    2.755907
# 203  Current health expenditure (% of GDP)    3.718785    3.885078
# 165  Current health expenditure (% of GDP)    3.378257    3.571847
# 34   Current health expenditure (% of GDP)    8.248144    8.624824
# 232  Current health expenditure (% of GDP)    3.101254    3.026238
# ...

# %% [markdown]
# ## Data Cleaning
